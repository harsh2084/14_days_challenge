# %% [markdown]
# Harsh.P

# %%
#import

import pandas as pd 
import numpy as np

# %% [markdown]
# Creation of data frame

# %%
dataframe = {'name':['Danish','Varun','PK','Muddasir'],'age':[17,20,19,21],'gamer level':[8.5,8.8,9.9,0.69]}

# %%
df = pd.DataFrame(dataframe)
print(df)
# Out:
#        name  age  gamer level
# 0    Danish   17         8.50
# 1     Varun   20         8.80
# 2        PK   19         9.90
# 3  Muddasir   21         0.69

# %% [markdown]
# Saving the dattaframe to csv file

# %%
df.to_csv("fileX2.csv" , index=False)

# %% [markdown]
# Reading Data from csv file

# %%
df =pd.read_csv("fileX2.csv")
print(df)
# Out:
#        name  age  gamer level
# 0    Danish   17         8.50
# 1     Varun   20         8.80
# 2        PK   19         9.90
# 3  Muddasir   21         0.69

# %% [markdown]
# Acessing and manipulating Data

# %%
df = pd.read_csv("data23.csv")

# %%
df
# Out:
#         Symbol Series       Date  Prev Close  Open Price  High Price  \
# 0    TATASTEEL     EQ  07-Sep-21     1437.00     1444.00     1459.00
# 1    TATASTEEL     EQ  08-Sep-21     1428.70     1426.00     1442.65
# 2    TATASTEEL     EQ  09-Sep-21     1429.85     1420.00     1451.95
# 3    TATASTEEL     EQ  13-Sep-21     1447.00     1447.00     1472.00
# 4    TATASTEEL     EQ  14-Sep-21     1463.45     1476.00     1476.00
# ..         ...    ...        ...         ...         ...         ...
# 246  TATASTEEL     EQ  30-Aug-22      104.85      106.50      108.50
# 247  TATASTEEL     EQ  01-Sep-22      108.30      107.00      107.75
# 248  TATASTEEL     EQ  02-Sep-22      106.40      107.00      107.00
# 249  TATASTEEL     EQ  05-Sep-22      105.50      106.05      107.30
# 250  TATASTEEL     EQ  06-Sep-22      106.90      107.40      108.80
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
rows, columns = df.shape 
print('rows', rows )
print('columns',columns)
# Out:
# rows 251
# columns 15

# %%
df.head(5)
df.tail(3)
# Out:
#         Symbol Series       Date  Prev Close  Open Price  High Price  \
# 248  TATASTEEL     EQ  02-Sep-22       106.4      107.00       107.0
# 249  TATASTEEL     EQ  05-Sep-22       105.5      106.05       107.3
# 250  TATASTEEL     EQ  06-Sep-22       106.9      107.40       108.8
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 248     105.00       105.6        105.5         105.79               45601352
# 249     105.80       106.8        106.9         106.80               40352735
# 250     106.05       108.5        108.6         107.47               59505849
#
#          Turnover  No. of Trades Deliverable Qty % Dly Qt to Traded Qty
# 248  4.824328e+09         199259        16669253                  36.55
# 249  4.309547e+09         151617        14171917                  35.12
# 250  6.395326e+09         188792        24885088                  41.82

# %%
print(df.iloc[0])
# Out:
# Symbol                       TATASTEEL
# Series                              EQ
# Date                         07-Sep-21
# Prev Close                      1437.0
# Open Price                      1444.0
# High Price                      1459.0
# Low Price                      1420.65
# Last Price                      1421.5
# Close Price                     1428.7
# Average Price                   1439.4
# Total Traded Quantity          6352717
# Turnover                  9144123989.0
# No. of Trades                   145446
# Deliverable Qty                1169405
# % Dly Qt to Traded Qty           18.41
# Name: 0, dtype: object

# %%
print(df.iloc[0,0:5])
# Out:
# Symbol        TATASTEEL
# Series               EQ
# Date          07-Sep-21
# Prev Close       1437.0
# Open Price       1444.0
# Name: 0, dtype: object

# %%
df.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   251.000000   251.000000   251.000000   251.000000   251.000000
# mean   1072.170518  1066.663546  1081.638247  1047.364143  1062.246813
# std     352.313161   363.535946   368.222332   356.798670   361.549502
# min     100.350000    98.100000   102.000000    97.150000   100.200000
# 25%    1033.600000  1018.500000  1035.650000   998.400000  1014.250000
# 50%    1173.000000  1168.300000  1186.600000  1151.550000  1169.100000
# 75%    1296.625000  1302.000000  1317.900000  1273.450000  1295.500000
# max    1463.450000  1476.000000  1476.000000  1449.000000  1470.000000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count   251.000000     251.000000           2.510000e+02  2.510000e+02
# mean   1062.597012    1064.420080           1.495817e+07  9.653725e+09
# std     361.786357     362.525149           2.169669e+07  5.027487e+09
# ...

# %%
df.head()
# Out:
#       Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  TATASTEEL     EQ  07-Sep-21     1437.00      1444.0     1459.00    1420.65
# 1  TATASTEEL     EQ  08-Sep-21     1428.70      1426.0     1442.65    1418.60
# 2  TATASTEEL     EQ  09-Sep-21     1429.85      1420.0     1451.95    1420.00
# 3  TATASTEEL     EQ  13-Sep-21     1447.00      1447.0     1472.00    1436.50
# 4  TATASTEEL     EQ  14-Sep-21     1463.45      1476.0     1476.00    1449.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      1421.5      1428.70        1439.40                6352717
# 1      1428.0      1429.85        1430.46                4676224
# 2      1446.9      1447.00        1441.08                5313030
# 3      1470.0      1463.45        1451.62                5670208
# 4      1451.4      1452.30        1461.40                5503767
#
#        Turnover  No. of Trades Deliverable Qty % Dly Qt to Traded Qty
# ...

# %% [markdown]
# reading columns

# %%
df.columns #Reading columns
# Out:
# Index(['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty'],
#       dtype='object')

# %%
df[["Date","Open Price","Close Price"]]
# Out:
#           Date  Open Price  Close Price
# 0    07-Sep-21     1444.00      1428.70
# 1    08-Sep-21     1426.00      1429.85
# 2    09-Sep-21     1420.00      1447.00
# 3    13-Sep-21     1447.00      1463.45
# 4    14-Sep-21     1476.00      1452.30
# ..         ...         ...          ...
# 246  30-Aug-22      106.50       108.30
# 247  01-Sep-22      107.00       106.40
# 248  02-Sep-22      107.00       105.50
# 249  05-Sep-22      106.05       106.90
# 250  06-Sep-22      107.40       108.60
#
# [251 rows x 3 columns]

# %%
del df ["Symbol"]
del df ["Series"]

# %%
df.dropna(inplace=True)

# %%
df.sort_values("Low Price", ascending=True).head()
# Out:
#           Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 224  28-Jul-22      959.40       98.10      102.00      97.15      100.20
# 225  29-Jul-22      100.35      103.00      109.30     102.15      107.80
# 245  29-Aug-22      107.35      104.05      105.65     103.25      105.05
# 241  23-Aug-22      105.05      104.20      108.25     103.50      107.90
# 240  22-Aug-22      110.05      109.50      109.60     104.70      105.20
#
#      Close Price  Average Price  Total Traded Quantity      Turnover  \
# 224       100.35          99.48              137156107  1.364434e+10
# 225       107.60         106.71              166959934  1.781604e+10
# 245       104.85         104.73               59895805  6.272783e+09
# 241       107.60         106.67               70531639  7.523872e+09
# 240       105.05         106.79               74037526  7.906795e+09
#
#      No. of Trades Deliverable Qty % Dly Qt to Traded Qty
# ...

# %%
df.sort_values("Average Price",ascending=False).head(10)
# Out:
#          Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 4   14-Sep-21     1463.45      1476.0     1476.00    1449.00     1451.40
# 5   15-Sep-21     1452.30      1452.3     1463.70    1444.40     1453.05
# 3   13-Sep-21     1447.00      1447.0     1472.00    1436.50     1470.00
# 6   16-Sep-21     1455.10      1460.0     1471.90    1431.25     1436.90
# 2   09-Sep-21     1429.85      1420.0     1451.95    1420.00     1446.90
# 0   07-Sep-21     1437.00      1444.0     1459.00    1420.65     1421.50
# 1   08-Sep-21     1428.70      1426.0     1442.65    1418.60     1428.00
# 28  18-Oct-21     1375.05      1418.0     1424.75    1391.10     1408.00
# 29  19-Oct-21     1411.05      1421.0     1426.55    1357.55     1369.00
# 7   17-Sep-21     1436.75      1437.0     1440.30    1360.00     1382.80
#
#     Close Price  Average Price  Total Traded Quantity      Turnover  \
# 4       1452.30        1461.40                5503767  8.043210e+09
# ...

# %%
df['Profit']= df['Open Price']- df['Close Price']

# %%
df.sort_values("Profit", ascending=True).head()
# Out:
#           Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 120  28-Feb-22     1145.35     1134.00     1225.00    1129.20     1217.90
# 121  02-Mar-22     1220.75     1220.75     1299.60    1218.55     1288.75
# 89   13-Jan-22     1147.20     1154.00     1225.50    1152.15     1219.00
# 171  17-May-22     1103.50     1124.00     1197.20    1115.35     1188.65
# 101  01-Feb-22     1085.55     1104.90     1174.45    1086.40     1166.55
#
#      Close Price  Average Price  Total Traded Quantity      Turnover  \
# 120      1220.75        1196.83               17605446  2.107077e+10
# 121      1289.35        1280.64               24847532  3.182069e+10
# 89       1221.15        1200.08               15723116  1.886896e+10
# 171      1188.70        1159.41               11287601  1.308691e+10
# 101      1167.35        1134.27               17075268  1.936795e+10
#
#      No. of Trades Deliverable Qty % Dly Qt to Traded Qty  Profit
# ...

# %% [markdown]
# Profitable Days

# %%
len( df.loc[df["Profit"] >= 1] )
# Out:
# 132

# %% [markdown]
# Loss Days

# %%
len( df.loc[df["Profit"] <= 1] )
# Out:
# 122

# %%
df["Date"].head()
# Out:
# 0    07-Sep-21
# 1    08-Sep-21
# 2    09-Sep-21
# 3    13-Sep-21
# 4    14-Sep-21
# Name: Date, dtype: object

# %%
yum = df["Date"].str.split("-", n = 3, expand=True).head()

# %%
yum
# Out:
#     0    1   2
# 0  07  Sep  21
# 1  08  Sep  21
# 2  09  Sep  21
# 3  13  Sep  21
# 4  14  Sep  21

# %%
df["Dated"] = yum[0]
df["Month"] = yum[1]
df["Year"] = yum[2]

# %% [markdown]
# Most Profits Made in a Year

# %%
df.groupby(["Year"]).sum()
# Out:
#       Prev Close  Open Price  High Price  Low Price  Last Price  Close Price  \
# Year
# 21        7206.0      7213.0      7301.6    7144.75      7217.8       7221.3
#
#       Average Price  Total Traded Quantity      Turnover  No. of Trades  \
# Year
# 21          7223.96               27515946  3.976396e+10         664990
#
#       Profit
# Year
# 21      -8.3
